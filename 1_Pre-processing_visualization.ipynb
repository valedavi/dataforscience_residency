# %% [markdown]
# We will use pandas and bokeh to respectively process and visualize my data.

# %%
import pandas as pd
from bokeh.plotting import Figure, output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
pd.set_option('plotting.backend', 'pandas_bokeh')
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# "neurite_soma_t" is a csv file containing the data of outgrowth of a neuronal culture as I received it from a post-doc in my lab who did the analysis.
#
# Briefly, the experiment consisted in knocking out and overexpressing one protein to see its effect on neuronal growth, thus the three conditions: wt (wild type control, neuronal culture expressing normal amount of this protein), ko (knocked-out, culture with no protein), and oe (overexpression, more protein present in these cells).
#
# The wt cells were in the A1 wells, the ko in B1 and the overexpression in the A2. There are around 15 samples per condition. Images of the cultures were taken twice a day (thus the timepoints 0.0 to 3.0), and masks for neurites and somas were generated and used to get the three values: neurite_area, soma_count and norm_neurite_area (neurite area normalised by soma count).

# %%
df = pd.read_csv('neurite_soma_t.csv')
df
# Out:
#      wt   A1_7                  t          0.0           0.5           1.0  \
# 0    wt   A1_7       neurite_area  4497.480000  14814.776000  23938.894400
# 1    wt   A1_7  Norm_neurite_area    10.139246     33.398851     53.968522
# 2    wt   A1_7         soma_count   324.000000    350.000000    390.000000
# 3    wt   A1_8                  t     0.000000      0.500000      1.000000
# 4    wt   A1_8       neurite_area  6743.913600  15385.225600  23423.798400
# ..   ..    ...                ...          ...           ...           ...
# 198  oe  A2_20         soma_count   650.000000    400.000000    433.000000
# 199  oe  A2_10                  t     0.000000      0.500000      1.000000
# 200  oe  A2_10       neurite_area  3959.320000  10440.304000  24444.764800
# 201  oe  A2_10  Norm_neurite_area     7.378924     19.457436     45.557336
# 202  oe  A2_10         soma_count   701.000000    401.000000    502.000000
#
#               1.5           2.0           2.5            3.0
# ...

# %% [markdown]
# There are several problems in this table. First, we will just need the normalized neurite area and we don't need to repeat the "t" line (time in days) every three lines because it's always the same. Therefore, we will drop these lines and then "t" column. All the int values will be just "norm_neurite_area" hereafter.

# %%
df.drop(df[df['t'] == 't'].index, inplace= True)
df.drop(df[df['t'] == 'neurite_area'].index, inplace= True)
df.drop(df[df['t'] == 'soma_count'].index, inplace= True)
df.drop('t', axis = 1, inplace = True)
df
# Out:
#      wt   A1_7        0.0        0.5         1.0         1.5         2.0  \
# 1    wt   A1_7  10.139246  33.398851   53.968522   99.652326  130.714818
# 5    wt   A1_8  19.645192  44.817553   68.234119  133.149249  156.064160
# 9    wt  A1_13  14.036711  30.220251   55.853066  134.049296  130.998539
# 13   wt  A1_18  12.222726  28.174637   52.006059  108.943644  136.716430
# 17   wt  A1_15  14.229548  40.654870   64.781890  120.879015  154.748913
# 21   wt  A1_14  15.940435  47.885643   68.685414  135.190939  159.578443
# 25   wt  A1_22  22.472099  44.573233   69.051675  135.522273  150.047368
# 29   wt  A1_19  15.730581  35.304466   67.327666  121.669968  148.433397
# 33   wt  A1_24  10.964381  37.887689   61.180985  128.804146  168.664286
# 37   wt   A1_9  13.480663  36.683613   55.501083  122.413803  156.473806
# 41   wt  A1_10  17.351088  43.227906   63.003243  127.329512  154.397053
# 45   wt  A1_12  13.732232  43.850888   61.002450  128.689798  138.387661
# ...

# %% [markdown]
# We now want to rename the "A1_7" coloumn with what it actually represents (samples). In place of the "wt" column (representing the category), we will add this information to the values in "sample", as all the wt are in the A1 samples, all the ko in the B1 and all the oe in the A2 samples. We will then drop the "wt" column.

# %%
df.drop('wt', axis = 1, inplace = True)
df = df.replace({'A1':'wt', 'A2':'oe', 'B1':'ko'}, regex=True)
df.rename(columns={'A1_7': 'samples'}, inplace = True)
df
# Out:
#     samples        0.0        0.5         1.0         1.5         2.0  \
# 1      wt_7  10.139246  33.398851   53.968522   99.652326  130.714818
# 5      wt_8  19.645192  44.817553   68.234119  133.149249  156.064160
# 9     wt_13  14.036711  30.220251   55.853066  134.049296  130.998539
# 13    wt_18  12.222726  28.174637   52.006059  108.943644  136.716430
# 17    wt_15  14.229548  40.654870   64.781890  120.879015  154.748913
# 21    wt_14  15.940435  47.885643   68.685414  135.190939  159.578443
# 25    wt_22  22.472099  44.573233   69.051675  135.522273  150.047368
# 29    wt_19  15.730581  35.304466   67.327666  121.669968  148.433397
# 33    wt_24  10.964381  37.887689   61.180985  128.804146  168.664286
# 37     wt_9  13.480663  36.683613   55.501083  122.413803  156.473806
# 41    wt_10  17.351088  43.227906   63.003243  127.329512  154.397053
# 45    wt_12  13.732232  43.850888   61.002450  128.689798  138.387661
# ...

# %% [markdown]
# We will now organise my data in order to have the timepoints as the index (and as integers) to be able to plot the neurite area values of each sample over time easily.

# %%
df.set_index(['samples'], inplace = True)
df = df.T
df
# Out:
# samples        wt_7        wt_8       wt_13       wt_18       wt_15  \
# 0.0       10.139246   19.645192   14.036711   12.222726   14.229548
# 0.5       33.398851   44.817553   30.220251   28.174637   40.654870
# 1.0       53.968522   68.234119   55.853066   52.006059   64.781890
# 1.5       99.652326  133.149249  134.049296  108.943644  120.879015
# 2.0      130.714818  156.064160  130.998539  136.716430  154.748913
# 2.5      160.650726  219.425054  175.119911  167.112504  193.146706
# 3.0      284.827896  314.762013  261.716215  278.390104  302.760949
#
# samples       wt_14       wt_22       wt_19       wt_24        wt_9  ...  \
# 0.0       15.940435   22.472099   15.730581   10.964381   13.480663  ...
# 0.5       47.885643   44.573233   35.304466   37.887689   36.683613  ...
# 1.0       68.685414   69.051675   67.327666   61.180985   55.501083  ...
# 1.5      135.190939  135.522273  121.669968  128.804146  122.413803  ...
# ...

# %%
df.index.rename('day', inplace = True)
df.index.astype(float)
df
# Out:
# samples        wt_7        wt_8       wt_13       wt_18       wt_15  \
# day
# 0.0       10.139246   19.645192   14.036711   12.222726   14.229548
# 0.5       33.398851   44.817553   30.220251   28.174637   40.654870
# 1.0       53.968522   68.234119   55.853066   52.006059   64.781890
# 1.5       99.652326  133.149249  134.049296  108.943644  120.879015
# 2.0      130.714818  156.064160  130.998539  136.716430  154.748913
# 2.5      160.650726  219.425054  175.119911  167.112504  193.146706
# 3.0      284.827896  314.762013  261.716215  278.390104  302.760949
#
# samples       wt_14       wt_22       wt_19       wt_24        wt_9  ...  \
# day                                                                  ...
# 0.0       15.940435   22.472099   15.730581   10.964381   13.480663  ...
# 0.5       47.885643   44.573233   35.304466   37.887689   36.683613  ...
# 1.0       68.685414   69.051675   67.327666   61.180985   55.501083  ...
# ...

# %% [markdown]
# Finally, we will express all the values relatively to the first time point, as we are not interested in the starting situation but just in the way the neurites grow.

# %%
df = df - df.loc['0.0']
df
# Out:
# samples        wt_7        wt_8       wt_13       wt_18       wt_15  \
# day
# 0.0        0.000000    0.000000    0.000000    0.000000    0.000000
# 0.5       23.259605   25.172361   16.183540   15.951911   26.425322
# 1.0       43.829276   48.588928   41.816356   39.783333   50.552342
# 1.5       89.513080  113.504058  120.012585   96.720919  106.649467
# 2.0      120.575571  136.418969  116.961828  124.493704  140.519365
# 2.5      150.511480  199.779863  161.083200  154.889778  178.917158
# 3.0      274.688650  295.116821  247.679504  266.167378  288.531401
#
# samples       wt_14       wt_22       wt_19       wt_24        wt_9  ...  \
# day                                                                  ...
# 0.0        0.000000    0.000000    0.000000    0.000000    0.000000  ...
# 0.5       31.945208   22.101134   19.573885   26.923307   23.202951  ...
# 1.0       52.744978   46.579577   51.597085   50.216604   42.020420  ...
# ...

# %% [markdown]
# We will now plot the neurite area values of each sample over time. We can see that I have three categories of growth, we will further dig into this in the next code.

# %%
df.plot(ylabel= 'normalised neurite area', title ='Delta neurite growth over 3 days')
# Out:
#   <div class="bk-root" id="31bc3158-ed5c-439d-bdfb-adac4d95aeae" data-root-id="1003"></div>
# Figure(id='1003', ...)

# %% [markdown]
# Finally, we will save the dataframe in pkl format, to preserve the structure of the dataframe in the next notebook.

# %%
df.to_pickle('pre-processed_norm_neurite_area_t.pkl')
